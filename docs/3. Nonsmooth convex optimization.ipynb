# %%
import specular
print(specular.__version__)
# Out:
# 0.7.2

# %%
specular.optimization.StepSize.__options__
# Out:
# ['constant',
#  'not_summable',
#  'square_summable_not_summable',
#  'geometric_series',
#  'user_defined']
