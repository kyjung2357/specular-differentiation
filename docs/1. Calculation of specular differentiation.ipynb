# %%
pip install specular-differentiation
# Out:
# Requirement already satisfied: specular-differentiation in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.12.0)
# Requirement already satisfied: numpy>=2.4.0 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from specular-differentiation) (2.4.1)
# Requirement already satisfied: ipython>=8.12.3 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from specular-differentiation) (8.12.3)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from specular-differentiation) (3.10.8)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from specular-differentiation) (2.3.3)
# Requirement already satisfied: tqdm>=4.67.1 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from specular-differentiation) (4.67.1)
# Requirement already satisfied: backcall in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=8.12.3->specular-differentiation) (0.2.0)
# Requirement already satisfied: decorator in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=8.12.3->specular-differentiation) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=8.12.3->specular-differentiation) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=8.12.3->specular-differentiation) (0.1.7)
# Requirement already satisfied: pickleshare in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=8.12.3->specular-differentiation) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=8.12.3->specular-differentiation) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=8.12.3->specular-differentiation) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=8.12.3->specular-differentiation) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=8.12.3->specular-differentiation) (5.14.3)
# Requirement already satisfied: colorama in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython>=8.12.3->specular-differentiation) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=8.12.3->specular-differentiation) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jedi>=0.16->ipython>=8.12.3->specular-differentiation) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.10.8->specular-differentiation) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.10.8->specular-differentiation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.10.8->specular-differentiation) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.10.8->specular-differentiation) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.10.8->specular-differentiation) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.10.8->specular-differentiation) (11.2.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.10.8->specular-differentiation) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.10.8->specular-differentiation) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=2.3.3->specular-differentiation) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=2.3.3->specular-differentiation) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->specular-differentiation) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython>=8.12.3->specular-differentiation) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython>=8.12.3->specular-differentiation) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\keeyobee\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack-data->ipython>=8.12.3->specular-differentiation) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install --upgrade specular-differentiation

# %%
import specular
import math
import numpy as np

print("version: ", specular.__version__)
# Out:
# version:  0.12.0

# %% [markdown]
# ## 1. Calculation of specular differentiation

# %% [markdown]
# In `core.py`, there are four modules to calculate specular differentiation, depending on the dimension.

# %% [markdown]
# ### 1.1 The one-dimensional Euclidean space ($n=1$)

# %% [markdown]
# In $ℝ$, the *specular derivative* can be calculated using the function `derivative`.

# %%
def f(x):
    return max(x, 0.0)

print(specular.derivative(f, x=0.0))
# Out:
# 0.41421356237309515

# %% [markdown]
# ### 1.2 The $n$-dimensional Euclidean space ($n>1$)

# %% [markdown]
# In $ℝ^n$, the *specular directional derivative* of a function $f: ℝ^n \to ℝ$ at a point $x \in ℝ^n$ in the direction $v \in ℝ^n$ can be calculated using the function `directional_derivative`.

# %%
f = lambda x: math.sqrt(x[0]**2 + x[1]**2 + x[2]**2)
specular.directional_derivative(f, x=[0.0, 0.1, -0.1], v=[1.0, -1.0, 2.0])
# Out:
# -2.1213203434708223

# %% [markdown]
# Let $e_1, e_2, \ldots, e_n$ be the standard basis of $ℝ^n$.
# For each $i \in ℕ$ with $1 \leq i \leq n$, the *specular partial derivative* with respect to a variable $x_i$ can be calculated using the function `partial_derivative`, which yields the same result as `directional_derivative` with direction $v=e_i$.

# %%
def f(x):
    return math.sqrt(x[0]**2 + x[1]**2 + x[2]**2)

print(specular.partial_derivative(f, x=[0.1, 2.3, -1.2], i=2))
print(specular.directional_derivative(f, x=[0.1, 2.3, -1.2], v=[0.0, 1.0, 0.0]))
# Out:
# 0.8859268982863702
# 0.8859268982863702

# %% [markdown]
# Also, the *specular gradient* can be calculated using `gradient`.

# %%
def f(x):
    return np.linalg.norm(x)

print(specular.gradient(f, x=[0.1, 2.3, -1.2]))

print(specular.partial_derivative(f, x=[0.1, 2.3, -1.2], i=1))
print(specular.partial_derivative(f, x=[0.1, 2.3, -1.2], i=2))
print(specular.partial_derivative(f, x=[0.1, 2.3, -1.2], i=3))
# Out:
# [ 0.03851856  0.8859269  -0.46222273]
# 0.03851856078540371
# 0.8859268982863702
# -0.4622227292028128
