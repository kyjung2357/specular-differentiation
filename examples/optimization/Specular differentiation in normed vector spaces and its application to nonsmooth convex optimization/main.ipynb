# %%
import os
import sys

# current_dir = os.path.dirname(os.path.abspath(__file__))

# if current_dir not in sys.path:
#     sys.path.append(current_dir)

from analysis import run_single_trial

m, n = 50, 10
iteration = 100
part_of_iteration = 1000
trials = 20

file_id = "1"
lambda1 = 0.0
lambda2 = 1.0

run_single_trial(0, m, n, lambda1, lambda2, iteration)
# Out:
# Running the specular gradient method: 100%|██████████| 100/100 [00:00<00:00, 5634.02it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      17 lambda1 = 0.0
#      18 lambda2 = 1.0
# ---> 20 run_single_trial(0, m, n, lambda1, lambda2, iteration)
#
# File c:\Users\keeyobee\Research\specular-differentiation\examples\optimization\Specular differentiation in normed vector spaces and its application to nonsmooth convex optimization\analysis.py:76, in run_single_trial(trial_idx, m, n, lambda1, lambda2, iteration)
#      74 # SSPEG
#      75 start_time = time.time()
# ---> 76 _, res = specular.gradient_method(
#      77     f=f, x_0=x_0, step_size=step_size_obj, form='stochastic', tol=1e-10, max_iter=iteration, f_j=f_stochastic, m=m, print_bar=True # type: ignore
#      78 ).history()
#      79 trial_results["SSPEG"] = ensure_length(res, iteration)
#      80 trial_times["SSPEG"] = time.time() - start_time
#
# TypeError: gradient_method() got an unexpected keyword argument 'm'
