# %%
import specular
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Figure 1

# %%
# Objective Function
def f(x):
    return np.sum([np.abs(x - i/100) + np.abs(x + i/100) - 2*i/100 for i in range(99)])

x_0 = -1.0
x_end = 1.0
X = np.linspace(x_0, x_end, 500)       
Y = np.array([f(x) for x in X])            

plt.figure(figsize=(5, 3))
plt.plot(X, Y, label='$f(x)$')
plt.title('The objective function')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.legend()
plt.grid(True)
plt.show()

# %%
step_size = specular.StepSize(name='not_summable', parameters=1.0)
specular.gradient_method(f=f, x_0=x_0, step_size=step_size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 step_size = specular.StepSize(name='not_summable', parameters=1.0)
# ----> 2 specular.gradient_method(f=f, x_0=x_0, step_size=step_size)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\specular\optimization\solver.py:68, in gradient_method(f, x_0, step_size, h, form, tol, zero_tol, max_iter, f_j, first_iter, record_history, record_time)
#      65         raise TypeError(f"Unknown form '{form}'. Supported forms: {SUPPORTED_METHODS}")
#      67 else:
# ---> 68     raise TypeError(f"Unknown form '{form}'. Supported forms: {SUPPORTED_METHODS}")
#      70 if record_time:
#      71     print("\n")
#
# TypeError: Unknown form 'specular gradient'. Supported forms: ['specular gradient', 'implicit', 'stochastic', 'hybrid']
